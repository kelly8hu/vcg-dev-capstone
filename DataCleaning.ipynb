# %%
import numpy as np
import pandas as pd
import joblib

# %%
df_1 = _deepnote_execute_sql('SELECT *\nFROM \'Food Ingredients and Recipe Dataset with Image Name Mapping.csv\'', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_1
# Out:
#        column0                                            column1  \
# 0          NaN                                              Title
# 1          0.0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 2          1.0                    Crispy Salt and Pepper Potatoes
# 3          2.0                        Thanksgiving Mac and Cheese
# 4          3.0                 Italian Sausage and Bread Stuffing
# ...        ...                                                ...
# 13497  13496.0                               Brownie Pudding Cake
# 13498  13497.0  Israeli Couscous with Roasted Butternut Squash...
# 13499  13498.0  Rice with Soy-Glazed Bonito Flakes and Sesame ...
# 13500  13499.0                                        Spanakopita
# 13501  13500.0  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                                  column2  \
# 0                                            Ingredients
# 1      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 2      ['2 large egg whites', '1 pound new potatoes (...
# 3      ['1 cup evaporated milk', '1 cup whole milk', ...
# 4      ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...                                                  ...
# 13497  ['1 cup all-purpose flour', '2/3 cup unsweeten...
# 13498  ['1 preserved lemon', '1 1/2 pound butternut s...
# 13499  ['Leftover katsuo bushi (dried bonito flakes) ...
# 13500  ['1 stick (1/2 cup) plus 1 tablespoon unsalted...
# 13501  ['12 medium to large fresh poblano chiles (2 1...
#
#                                                  column3  \
# 0                                           Instructions
# 1      Pat chicken dry with paper towels, season all ...
# 2      Preheat oven to 400°F and line a rimmed baking...
# 3      Place a rack in middle of oven; preheat to 400...
# 4      Preheat oven to 350°F with rack in middle. Gen...
# ...                                                  ...
# 13497  Preheat the oven to 350°F. Into a bowl sift to...
# 13498  Preheat oven to 475°F.\nHalve lemons and scoop...
# 13499  If using katsuo bushi flakes from package, moi...
# 13500  Melt 1 tablespoon butter in a 12-inch heavy sk...
# 13501  Lay 4 chiles on their sides on racks of gas bu...
#
#                                                  column4  \
# 0                                             Image_Name
# 1      miso-butter-roast-chicken-acorn-squash-panzanella
# 2             crispy-salt-and-pepper-potatoes-dan-kluger
# 3             thanksgiving-mac-and-cheese-erick-williams
# 4              italian-sausage-and-bread-stuffing-240559
# ...                                                  ...
# 13497                         brownie-pudding-cake-14408
# 13498  israeli-couscous-with-roasted-butternut-squash...
# 13499  rice-with-soy-glazed-bonito-flakes-and-sesame-...
# 13500                                 spanakopita-107344
# 13501  mexican-poblano-spinach-and-black-bean-lasagne...
#
#                                                  column5
# 0                                    Cleaned_Ingredients
# 1      ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 2      ['2 large egg whites', '1 pound new potatoes (...
# 3      ['1 cup evaporated milk', '1 cup whole milk', ...
# 4      ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...                                                  ...
# 13497  ['1 cup all-purpose flour', '2/3 cup unsweeten...
# 13498  ['1 preserved lemon', '1 1/2 pound butternut s...
# 13499  ['Leftover katsuo bushi (dried bonito flakes) ...
# 13500  ['1 stick (1/2 cup) plus 1 tablespoon unsalted...
# 13501  ['12 medium to large fresh poblano chiles (2 1...
#
# [13502 rows x 6 columns]

# %% [markdown]
# Cleaning any NaN values from the data

# %%
name = 'Food Ingredients and Recipe Dataset with Image Name Mapping.csv'
RecipeData = pd.read_csv(name).dropna()
RecipeData["Cleaned_Ingredients"]
# Out:
# 0        ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1        ['2 large egg whites', '1 pound new potatoes (...
# 2        ['1 cup evaporated milk', '1 cup whole milk', ...
# 3        ['1 (¾- to 1-pound) round Italian loaf, cut in...
# 4        ['1 teaspoon dark brown sugar', '1 teaspoon ho...
#                                ...
# 13496    ['1 cup all-purpose flour', '2/3 cup unsweeten...
# 13497    ['1 preserved lemon', '1 1/2 pound butternut s...
# 13498    ['Leftover katsuo bushi (dried bonito flakes) ...
# 13499    ['1 stick (1/2 cup) plus 1 tablespoon unsalted...
# 13500    ['12 medium to large fresh poblano chiles (2 1...
# Name: Cleaned_Ingredients, Length: 13493, dtype: object

# %% [markdown]
# The beta of the function will take in a list of words inputted by the user and then return a score that depends on if the word shows up in the ingredients of a specified recipe.

# %%
#using dataset RecipeData

def fs(myIngredients, ingredients):
    score = 0
    for ingredient in myIngredients:
        if ingredient in ingredients:
            score += 1
    return score

    
def findScore(myIngredients):
    return lambda x: fs(myIngredients, x)


def findBestRecipe(listOfIngredients):
    func = findScore(listOfIngredients)
    RecipeDataCopy = RecipeData.copy()
    RecipeDataCopy['Score'] = RecipeDataCopy["Cleaned_Ingredients"].apply(func)
    R = RecipeDataCopy.sort_values(by='Score', ascending=False)
    return R.iloc[0]['Title']

# %%
'chicken','butter','salt','rice'
# Out:
# ('chicken', 'butter', 'salt', 'rice')

# %% [markdown]
# ### Recipe Filter

# %% [markdown]
# Input a list of ingredients here:

# %%
findBestRecipe([])
# Out:
# 'Miso-Butter Roast Chicken With Acorn Squash Panzanella'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dcb80ec8-6073-40ee-9e6f-92835c1aacde' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
